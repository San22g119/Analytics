# %% [markdown]
# <a href="https://colab.research.google.com/github/San22g119/Analytics/blob/main/Nutrients_Reports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
nutrients=pd.read_csv("/content/nutrients_csvfile.csv")
nutrients.head()
# Out:
#                     Food Measure  Grams Calories Protein Fat Sat.Fat Fiber  \
# 0             Cows' milk   1 qt.    976      660      32  40      36     0
# 1              Milk skim   1 qt.    984      360      36   t       t     0
# 2             Buttermilk   1 cup    246      127       9   5       4     0
# 3  Evaporated, undiluted   1 cup    252      345      16  20      18     0
# 4         Fortified milk  6 cups  1,419    1,373      89  42      23   1.4
#
#   Carbs        Category
# 0    48  Dairy products
# 1    52  Dairy products
# 2    13  Dairy products
# 3    24  Dairy products
# 4   119  Dairy products

# %% [markdown]
# # **Data Cleaning**

# %%
nutrients.head()
# Out:
#                     Food Measure  Grams Calories Protein Fat Sat.Fat Fiber  \
# 0             Cows' milk   1 qt.    976      660      32  40      36     0
# 1              Milk skim   1 qt.    984      360      36   t       t     0
# 2             Buttermilk   1 cup    246      127       9   5       4     0
# 3  Evaporated, undiluted   1 cup    252      345      16  20      18     0
# 4         Fortified milk  6 cups  1,419    1,373      89  42      23   1.4
#
#   Carbs        Category
# 0    48  Dairy products
# 1    52  Dairy products
# 2    13  Dairy products
# 3    24  Dairy products
# 4   119  Dairy products

# %%
nutrients=nutrients.replace("t",0)
nutrients=nutrients.replace("t'",0)

nutrients.head()
# Out:
#                     Food Measure  Grams Calories Protein Fat Sat.Fat Fiber  \
# 0             Cows' milk   1 qt.    976      660      32  40      36     0
# 1              Milk skim   1 qt.    984      360      36   0       0     0
# 2             Buttermilk   1 cup    246      127       9   5       4     0
# 3  Evaporated, undiluted   1 cup    252      345      16  20      18     0
# 4         Fortified milk  6 cups  1,419    1,373      89  42      23   1.4
#
#   Carbs        Category
# 0    48  Dairy products
# 1    52  Dairy products
# 2    13  Dairy products
# 3    24  Dairy products
# 4   119  Dairy products

# %%
nutrients.dtypes
# Out:
# Food        object
# Measure     object
# Grams       object
# Calories    object
# Protein     object
# Fat         object
# Sat.Fat     object
# Fiber       object
# Carbs       object
# Category    object
# dtype: object

# %%
print(nutrients.isnull().any())
print('-'*245)
print(nutrients.describe())
print('-'*245)
# Out:
# Food        False
# Measure     False
# Grams       False
# Calories     True
# Protein     False
# Fat         False
# Sat.Fat      True
# Fiber       False
# Carbs       False
# Category    False
# dtype: bool
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
#           Food Measure Grams Calories Protein  Fat Sat.Fat Fiber Carbs  \
# count      335     335   335      334     335  335     333   335   335
# unique     329      61   103      152      40   44      38    57    80
# top     Butter   1 cup   100      100       1    0       0     0     0
# freq         3     120    38       14      53  116     174   116    45
#
#                              Category
# count                             335
# unique                             16
# top     Breads cereals fastfoodgrains
# freq                               45
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
nutrients.shape
# Out:
# (335, 10)

# %%
# First, clean the 'Calories' column by removing commas and converting to numeric
nutrients['Calories'] = nutrients['Calories'].astype(str).str.replace(',', '', regex=False)
nutrients['Calories'] = pd.to_numeric(nutrients['Calories'], errors='coerce')

cals = nutrients.sort_values(by='Calories', ascending=False)
top_20_cals = cals.head(20)
fig = px.bar(top_20_cals, x='Food', y='Calories', color='Calories', title='Top 10 calorie rich foods')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0cdc5e47-fd1c-4d27-95b3-8b8f07cd9c4a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0cdc5e47-fd1c-4d27-95b3-8b8f07cd9c4a")) {                    Plotly.newPlot(                        "0cdc5e47-fd1c-4d27-95b3-8b8f07cd9c4a",                        [{"alignmentgroup":"True","hovertemplate":"Food=%{x}\u003cbr\u003eCalories=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1373.0,1225.0,1100.0,992.0,815.0,806.0,770.0,748.0,692.0,690.0,677.0,665.0,660.0,530.0,515.0,505.0,480.0,480.0,475.0,475.0],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Fortified milk","White 20 slices or","Whole-wheat","Lard","Brown firm-packed dark sugar","Margarine","Puddings Sugar","Rice","White","(1\u002f2 cup ice cream)","Converted","Hydrogenated cooking fat","Cows' milk","Cranberry sauce sweetened","Powdered milk","Dates","Pot-pie","Lamb chop broiled","Pork sausage","Baked with cheese"],"xaxis":"x","y":[1373.0,1225.0,1100.0,992.0,815.0,806.0,770.0,748.0,692.0,690.0,677.0,665.0,660.0,530.0,515.0,505.0,480.0,480.0,475.0,475.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks": ...

# %%
cals= nutrients.sort_values(by='Calories', ascending= False)
top_20_cals=cals.head(20)
fig = px.bar(top_20, x='Food', y='Calories' , color='Calories',title=' Top 10 calorie rich foods')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5594fe56-2d94-4b9e-af1a-d014f103aaa0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5594fe56-2d94-4b9e-af1a-d014f103aaa0")) {                    Plotly.newPlot(                        "5594fe56-2d94-4b9e-af1a-d014f103aaa0",                        [{"alignmentgroup":"True","hovertemplate":"Calories=%{y}\u003cbr\u003eFood=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1100","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"1100","offsetgroup":"1100","orientation":"v","showlegend":true,"textposition":"auto","x":["Whole-wheat"],"xaxis":"x","y":["1100"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Calories=%{y}\u003cbr\u003eFood=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"1225","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"1225","offsetgroup":"1225","orientation":"v","showlegend":true,"textposition":"auto","x":["White 20 slices or"],"xaxis":"x","y":["1225"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Calories=%{y}\u003cbr\u003eFood=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"460","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"460","offsetgroup":"460","orientation":"v","showlegend":true,"textposition":"auto","x":["Flour"],"xaxis":"x","y":["460"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Calories=%{y}\u003cbr\u003eFood=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"260","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"260","offsetgroup":"260","orientation":"v","showlegend":true,"textposition":"auto","x":["Soybeans","Wheat-germ cereal toasted","Lima dry cooked"],"xaxis":"x","y":["260","260","260"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Calories=%{y}\u003cbr\u003eFood=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"255","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"255","offsetgroup":"255","orientation":"v","showlegend":true,"textposition":"auto","x":["Peppers with beef and crumbs"],"xaxis":"x","y":["255"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Calories=%{y}\u003cbr\u003eFood=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"475","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"475","offsetgroup":"475","orientation":"v","showlegend":true,"textposition":"auto","x":["Baked with cheese"],"xaxis":"x","y":["475"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Calories=%{y}\u003cbr\u003eFood=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"245","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"245","offsetgroup":"245","orientation":"v","showlegend":true,"textposition":"auto","x":["Wheat germ"],"xaxis":"x","y":["245"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Calories=%{y}\u003cbr\u003eFood=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"230","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"230","offsetgroup":"230","orientation":"v","showlegend":true,"textposition":"auto","x":["Red kidney"],"xaxis":"x","y":["230"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Calories=%{y}\u003cbr\u003eFood=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"748","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"748","offsetgroup":"748","orientation":"v","showlegend":true,"textposition":"auto","x":["Rice"],"xaxis":"x","y":["748"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Calories=%{y}\u003cbr\u003eFood=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"212","marker":{"color":"#FECB52","pattern":{"s ...

# %%
numeric_cols = ['Grams', 'Protein', 'Fat', 'Sat.Fat', 'Fiber', 'Carbs']
for col in numeric_cols:
    nutrients[col] = pd.to_numeric(nutrients[col], errors='coerce')

category_dist = nutrients.groupby(['Category']).sum()
category_dist
# Out:
#                                                                             Food  \
# Category
# Breads cereals fastfoodgrains  BiscuitsBran flakesBread cracked wheatRyeWhite...
# Dairy products                 Cows' milkMilk skimButtermilkEvaporated undilu...
# Desserts sweets                Apple bettyBread puddingCakesChocolate fudgeCu...
# DrinksAlcohol Beverages        BeerGinWinesTable (12.2% alcohol)Carbonated dr...
# Fats Oils Shortenings          YolksButterButterButterHydrogenated cooking fa...
# Fish Seafood                   ClamsCodCrab meatFish sticks friedFlounderHadd...
# Fruits A-F                     Watercress stems rawApple juice cannedApple vi...
# Fruits G-P                     Grapefruit sectionsGrapefruit fresh 5" diamete...
# Fruits R-Z                     RaisinsRaspberriesRaw redRhubarb sweetenedStra...
# Jams Jellies                   HoneypreservesJelliesMolassesCane SyrupBrown f...
# Meat Poultry                   Salt porkBaconBeefHamburgerGround leanRoast be...
# Seeds and Nuts                 Almondsroasted and saltedBrazil nutsCashewscoc...
# Soups                          Bean soupsBeef soupBouillonchicken soupClam ch...
# Vegetables A-E                 ArtichokeAsparagusBeansLimaLima dry cookedNavy...
# Vegetables F-P                 KaleKohlrabiLambs quarters steamedLentilsLettu...
# Vegetables R-Z                 Fresh steamed peasFrozen peasSplit cooked peas...
#
#                                                                          Measure  \
# Category
# Breads cereals fastfoodgrains  11 cup1 slice1 slice1-lb. loaf1-lb. loaf1 slic...
# Dairy products                 1 qt.1 qt.1 cup1 cup6 cups1 cup1 1/3 cups2/3 c...
# Desserts sweets                1 serving3/4 cup1 slice1 slice11 slice1 slice1...
# DrinksAlcohol Beverages        2 cups1 oz.1/2 cup1/2 cup12 oz.12 oz.12 oz.12 ...
# Fats Oils Shortenings          21T.1/2 cup1/4 lb.1/2 cup1/2 cup1/2 cup1 T.1 T...
# Fish Seafood                   3 oz.3 1/2 oz.3 oz.53 1/2 oz.3 oz.3 1/2 oz.1 s...
# Fruits A-F                     1 cup1 cup1/3 cup1 med1 cup1 cup1/2 cup3 med.1...
# Fruits G-P                     1 cup1/21 cup1 cup1 cup1 cup1/2 cup6-oz. can6-...
# Fruits R-Z                     1/2 cup1/2 cup3/4 cup1 cup1 cup1 cupI med.1 wedge
# Jams Jellies                                   2 T.1 T.1 T.1 T.1 T.1 cup2 T.2 T.
# Meat Poultry                   2 oz.2 slices3 oz.3 oz.3 oz.3 oz.3 oz.3 oz.3 o...
# Seeds and Nuts                 1/2 cup1/2 cup1/2 cup1/2 cup1/2 cup1/3 cup1/3 ...
# Soups                          1 cup1 cup1 cup1 cup1 cup1 cup1 cup1 cup1 cup1...
# Vegetables A-E                 1 large6 spears1 cup1 cup1 cup3/4 cup1 cup1 cu...
# Vegetables F-P                 1 cup1 cup1 cup1 cup1/4 head1/4 head411 1/3 cu...
# Vegetables R-Z                 1 cup1 cup4 cups1 cup1 pod1 large1 med.1 med.1...
#
#                                Grams  Calories  Protein  Fat  Sat.Fat   Fiber  \
# Category
# Breads cereals fastfoodgrains   5253   11921.0      403  207     99.0  115.91
# Dairy products                  7412    8434.0      503  396    322.0    4.40
# Desserts sweets                 2958    6608.0       78  163    150.0   20.50
# DrinksAlcohol Beverages         3284    1112.0        0    0      0.0    0.00
# Fats Oils Shortenings            695    3629.0      234  631    536.0  234.00
# Fish Seafood                    1892    2912.0      606  347    252.0  235.00
# Fruits A-F                      3844    3328.0       29   20     12.0   33.50
# Fruits G-P                      5412    4054.0       28   25     21.0   21.10
# Fruits R-Z                      1973    1228.0        7    1      0.0   17.40
# Jams Jellies                     422    1345.0        0    0      0.0    8.00
# Meat Poultry                    2784    7999.0      549  575    427.0    0.00
# Seeds and Nuts                   682    4089.0      120  368    232.0   18.60
# Soups                           2495    1191.0       59   41     43.0    4.00
# Vegetables A-E                  3685    1805.0      113    9      6.0   36.30
# Vegetables F-P                  1725     711.0       40    2      0.0   16.90
# Vegetables R-Z                  3460    2694.0      103   76     44.0   28.00
#
#                                 Carbs
# Category
# Breads cereals fastfoodgrains  2059.0
# Dairy products                  651.0
# Desserts sweets                1184.0
# DrinksAlcohol Beverages         167.0
# Fats Oils Shortenings           239.0
# Fish Seafood                    263.0
# Fruits A-F                      812.0
# Fruits G-P                     1009.0
# Fruits R-Z                      330.0
# Jams Jellies                    345.0
# Meat Poultry                     57.3
# Seeds and Nuts                  140.0
# Soups                           155.0
# Vegetables A-E                  356.8
# Vegetables F-P                  142.0
# Vegetables R-Z                  459.0

# %%
category_dist=nutrients.groupby(['Category']).sum()
from plotly.subplots import make_subplots
import plotly.graph_objects as go

fig = make_subplots(
    rows=2, cols=3,
    specs=[[{"type": "domain"},{"type": "domain"},{"type": "domain"}],[{"type": "domain"},{"type": "domain"},{"type": "domain"}]]
)

fig.add_trace(go.Pie(values=category_dist['Calories'].values, title='CALORIES', labels=category_dist.index,marker=dict(colors=['#100b','#f00560'], line=dict(color='#FFFFFF', width=2.5))),
              row=1, col=1)

fig.add_trace(go.Pie(values=category_dist['Fat'].values,title='FAT', labels=category_dist.index,marker=dict(colors=['#100b','#f00560'], line=dict(color='#FFFFFF', width=2.5))),
              row=1, col=2)

fig.add_trace(go.Pie(values=category_dist['Protein'].values,title='PROTEIN', labels=category_dist.index,marker=dict(colors=['#100b','#f00560'], line=dict(color='#FFFFFF', width=2.5))),
              row=1, col=3)

fig.add_trace(go.Pie(values=category_dist['Fiber'].values,title='FIBER', labels=category_dist.index,marker=dict(colors=['#100b','#f00560'], line=dict(color='#FFFFFF', width=2.5))),
              row=2, col=1)

fig.add_trace(go.Pie(values=category_dist['Sat.Fat'].values,title='SAT.FAT', labels=category_dist.index,marker=dict(colors=['#100b','#f00560'], line=dict(color='#FFFFFF', width=2.5))),
              row=2, col=2)

fig.add_trace(go.Pie(values=category_dist['Carbs'].values,title='CARBS', labels=category_dist.index,marker=dict(colors=['#100b','#f00560'], line=dict(color='#FFFFFF', width=2.5))),
              row=2, col=3)
fig.update_layout(title_text="Category wise distribution of all metrics",height=700, width=1000)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="636701ba-73d3-41f8-80af-8db26f8c5924" class="plotly-graph-div" style="height:700px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("636701ba-73d3-41f8-80af-8db26f8c5924")) {                    Plotly.newPlot(                        "636701ba-73d3-41f8-80af-8db26f8c5924",                        [{"labels":["Breads cereals fastfoodgrains","Dairy products","Desserts sweets","DrinksAlcohol Beverages","Fats Oils Shortenings","Fish Seafood","Fruits A-F","Fruits G-P","Fruits R-Z","Jams Jellies","Meat Poultry","Seeds and Nuts","Soups","Vegetables A-E","Vegetables F-P","Vegetables R-Z"],"marker":{"colors":["#100b","#f00560"],"line":{"color":"#FFFFFF","width":2.5}},"title":{"text":"CALORIES"},"values":[11921.0,8434.0,6608.0,1112.0,3629.0,2912.0,3328.0,4054.0,1228.0,1345.0,7999.0,4089.0,1191.0,1805.0,711.0,2694.0],"type":"pie","domain":{"x":[0.0,0.2888888888888889],"y":[0.575,1.0]}},{"labels":["Breads cereals fastfoodgrains","Dairy products","Desserts sweets","DrinksAlcohol Beverages","Fats Oils Shortenings","Fish Seafood","Fruits A-F","Fruits G-P","Fruits R-Z","Jams Jellies","Meat Poultry","Seeds and Nuts","Soups","Vegetables A-E","Vegetables F-P","Vegetables R-Z"],"marker":{"colors":["#100b","#f00560"],"line":{"color":"#FFFFFF","width":2.5}},"title":{"text":"FAT"},"values":[207,396,163,0,631,347,20,25,1,0,575,368,41,9,2,76],"type":"pie","domain":{"x":[0.35555555555555557,0.6444444444444445],"y":[0.575,1.0]}},{"labels":["Breads cereals fastfoodgrains","Dairy products","Desserts sweets","DrinksAlcohol Beverages","Fats Oils Shortenings","Fish Seafood","Fruits A-F","Fruits G-P","Fruits R-Z","Jams Jellies","Meat Poultry","Seeds and Nuts","Soups","Vegetables A-E","Vegetables F-P","Vegetables R-Z"],"marker":{"colors":["#100b","#f00560"],"line":{"color":"#FFFFFF","width":2.5}},"title":{"text":"PROTEIN"},"values":[403,503,78,0,234,606,29,28,7,0,549,120,59,113,40,103],"type":"pie","domain":{"x":[0.7111111111111111,1.0],"y":[0.575,1.0]}},{"labels":["Breads cereals fastfoodgrains","Dairy products","Desserts sweets","DrinksAlcohol Beverages","Fats Oils Shortenings","Fish Seafood","Fruits A-F","Fruits G-P","Fruits R-Z","Jams Jellies","Meat Poultry","Seeds and Nuts","Soups","Vegetables A-E","Vegetables F-P","Vegetables R-Z"],"marker":{"colors":["#100b","#f00560"],"line":{"color":"#FFFFFF","width":2.5}},"title":{"text":"FIBER"},"values":[115.91,4.4,20.5,0.0,234.0,235.0,33.5,21.1,17.4,8.0,0.0,18.6,4.0,36.3,16.9,28.0],"type":"pie","domain":{"x":[0.0,0.2888888888888889],"y":[0.0,0.425]}},{"labels":["Breads cereals fastfoodgrains","Dairy products","Desserts sweets","DrinksAlcohol Beverages","Fats Oils Shortenings","Fish Seafood","Fruits A-F","Fruits G-P","Fruits R-Z","Jams Jellies","Meat Poultry","Seeds and Nuts","Soups","Vegetables A-E","Vegetables F-P","Vegetables R-Z"],"marker":{"colors":["#100b","#f00560"],"line":{"color":"#FFFFFF","width":2.5}},"title":{"text":"SAT.FAT"},"values":[99.0,322.0,150.0,0.0,536.0,252.0,12.0,21.0,0.0,0.0,427.0,232.0,43.0,6.0,0.0,44.0],"type":"pie","domain":{"x":[0.35555555555555557,0.6444444444444445],"y":[0.0,0.425]}},{"labels":["Breads cereals fastfoodgrains","Dairy products","Desserts sweets","DrinksAlcohol Beverages","Fats Oils Shortenings","Fish Seafood","Fruits A-F","Fruits G-P","Fruits R-Z","Jams Jellies","Meat Poultry","Seeds and Nuts","Soups","Vegetables A-E","Vegetables F-P","Vegetables R-Z"],"marker":{"colors":["#100b","#f00560"],"line":{"color":"#FFFFFF","width":2.5}},"title":{"text":"CARBS"},"values":[2059.0,651.0,1184.0,167.0,239.0,263.0,812.0,1009.0,330.0,345.0,57.3,140.0,155.0,356.8,142.0,459.0],"type":"pie","domain":{"x":[0.7111111111111111,1.0],"y":[0.0,0.425]}}],                        {"template":{"data":{"histogram2dcontour":[{"type":"his ...
