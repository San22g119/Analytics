# %%
from PIL import Image
img = Image.open('/content/images (6).jpeg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=225x225>

# %%
from PIL import Image
img1 = Image.open('/content/culmen_depth.png')
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3887x2502>

# %%
from PIL import Image
img2 = Image.open('/content/lter_penguins.png')
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1800x1074>

# %% [markdown]
# ## Load Libraries

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Check the version of seaborn

# %%
sns.__version__
# Out:
# '0.13.2'

# %% [markdown]
# ### Explore the data of seaborn

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# ## Load the dataset

# %%
df = sns.load_dataset('penguins')
df.head(10)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
# 7  Adelie  Torgersen            39.2           19.6              195.0
# 8  Adelie  Torgersen            34.1           18.1              193.0
# 9  Adelie  Torgersen            42.0           20.2              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# 5       3650.0    Male
# ...

# %%
df.shape
# Out:
# (344, 7)

# %%
df.tail()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 339  Gentoo  Biscoe             NaN            NaN                NaN
# 340  Gentoo  Biscoe            46.8           14.3              215.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 342  Gentoo  Biscoe            45.2           14.8              212.0
# 343  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
#
#                       75%     max
# bill_length_mm       48.5    59.6
# bill_depth_mm        18.7    21.5
# flipper_length_mm   213.0   231.0
# body_mass_g        4750.0  6300.0

# %%
df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
df.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
df.describe(include='all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      344     344      342.000000     342.000000         342.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       152     168             NaN            NaN                NaN
# mean       NaN     NaN       43.921930      17.151170         200.915205
# std        NaN     NaN        5.459584       1.974793          14.061714
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.225000      15.600000         190.000000
# 50%        NaN     NaN       44.450000      17.300000         197.000000
# 75%        NaN     NaN       48.500000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex
# count    342.000000   333
# unique          NaN     2
# ...

# %%
df.drop(['sex','island','species'], axis=1, inplace=True)

# %%
df.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.heatmap(df.corr(), cmap= 'viridis', annot=True);

# %% [markdown]
# ## Histogram

# %%
df.hist(figsize=(12,8));
plt.show()

# %% [markdown]
# ## Box plot

# %%
df.plot(kind= 'box', subplots=True, layout=(3,2), sharex=False, sharey= False , figsize=(8,12))
plt.show()

# %% [markdown]
# ## Value Counts

# %%
df.value_counts()
# Out:
# bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 59.6            17.0           230.0              6050.0         1
# 32.1            15.5           188.0              3050.0         1
# 33.1            16.1           178.0              2900.0         1
# 33.5            19.0           190.0              3600.0         1
# 34.0            17.1           185.0              3400.0         1
#                                                                 ..
# 35.0            17.9           192.0              3725.0         1
#                                190.0              3450.0         1
# 34.6            21.1           198.0              4400.0         1
#                 17.2           189.0              3200.0         1
# 34.5            18.1           187.0              2900.0         1
# Name: count, Length: 342, dtype: int64

# %%
df=sns.load_dataset('penguins')
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
df.species.value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %% [markdown]
# ## Count Plots

# %%
sns.countplot(data=df, x='sex', palette='summer');
# Out:
# /tmp/ipython-input-26-934911939.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='sex', palette='summer');

# %%
sns.countplot(data=df, x='island', palette='RdPu');

# %%
sns.countplot(data=df, x='species', palette='YlOrRd');

# %% [markdown]
# ### Adding more parameters to countplot

# %%
sns.countplot(data= df, x='sex', palette='rocket', hue='species');

# %%
sns.countplot(data= df, x= 'island', hue='species', palette='husl');

# %%
sns.countplot(data= df, x= 'island', hue='sex', palette='spring');

# %% [markdown]
# ## Pairplots

# %%
sns.pairplot(data=df, hue='species',palette='mako');

# %% [markdown]
# ## Violin Plot

# %%
ax = sns.violinplot(x= 'sex', y= 'flipper_length_mm', data=df, size=8)

# %%
ax = sns.violinplot(x= 'species', y= 'flipper_length_mm', data=df, size=8, palette='seismic')

# %%
 ax = sns.violinplot(x= 'species', y= 'body_mass_g', data=df, size=8, palette='YlGn');

# %% [markdown]
# ### Check the Null Values

# %%
df.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %% [markdown]
# ## Drop The Null Values

# %%
df.dropna(inplace=True)
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %% [markdown]
# ### Dealing with the Missing Values

# %% [markdown]
# #### Create a copy of the dataset

# %%
df1 = df.copy()
df1.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
df1.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %% [raw]
# Species : Map function
# island: Label Encoding
# Sex : One Hot Encoding

# %% [markdown]
# ### Drop the species column from df1

# %%
df2=sns.load_dataset('penguins')
df2.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
Y = df2.species
Y.head()
# Out:
# 0    Adelie
# 1    Adelie
# 2    Adelie
# 3    Adelie
# 4    Adelie
# Name: species, dtype: object

# %%
Y.unique()
# Out:
# array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object)

# %%
Y = Y.map({'Adelie': 0, 'Chinstrap':1, 'Gentoo':2})
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: species, dtype: int64

# %%
#### Drop the species column from df1

df2.drop('species', inplace=True, axis=1)

# %%
df1.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %% [markdown]
# ### One Hot Encoding on sex variable

# %%
pd.get_dummies(df1['sex']).head()
# Out:
#    Female   Male
# 0   False   True
# 1    True  False
# 2    True  False
# 4    True  False
# 5   False   True

# %%
se=pd.get_dummies(df1['sex'], drop_first=True)
se.head(3)
# Out:
#     Male
# 0   True
# 1  False
# 2  False

# %% [raw]
#  we have dropped the first column because only one column is sufficient to determine
# the gender of the penguins either will be male(1)or not(0), that means a female

# %% [markdown]
# ### Label Encoding

# %%
df1.island.unique()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df1['island']= le.fit_transform(df1['island'])

df1['island']
# Out:
# 0      2
# 1      2
# 2      2
# 4      2
# 5      2
#       ..
# 338    0
# 340    0
# 341    0
# 342    0
# 343    0
# Name: island, Length: 333, dtype: int64

# %%
df1.head()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie       2            39.1           18.7              181.0
# 1  Adelie       2            39.5           17.4              186.0
# 2  Adelie       2            40.3           18.0              195.0
# 4  Adelie       2            36.7           19.3              193.0
# 5  Adelie       2            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %% [markdown]
# ### Concatenation

# %%
df2 = pd.concat([df1, se], axis=1)

# %%
df2.head()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie       2            39.1           18.7              181.0
# 1  Adelie       2            39.5           17.4              186.0
# 2  Adelie       2            40.3           18.0              195.0
# 4  Adelie       2            36.7           19.3              193.0
# 5  Adelie       2            39.3           20.6              190.0
#
#    body_mass_g     sex   Male
# 0       3750.0    Male   True
# 1       3800.0  Female  False
# 2       3250.0  Female  False
# 4       3450.0  Female  False
# 5       3650.0    Male   True

# %% [markdown]
# ### drop the sex column

# %%
df2.drop('sex', axis=1, inplace=True);

# %%
df2.head()
# Out:
#   species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie       2            39.1           18.7              181.0
# 1  Adelie       2            39.5           17.4              186.0
# 2  Adelie       2            40.3           18.0              195.0
# 4  Adelie       2            36.7           19.3              193.0
# 5  Adelie       2            39.3           20.6              190.0
#
#    body_mass_g   Male
# 0       3750.0   True
# 1       3800.0  False
# 2       3250.0  False
# 4       3450.0  False
# 5       3650.0   True

# %%
df2.dtypes
# Out:
# species               object
# island                 int64
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# Male                    bool
# dtype: object

# %%
Y.dtypes
# Out:
# dtype('int64')

# %%
X = df2

# %%
from sklearn.model_selection import train_test_split

# Load the dataset again to ensure consistent rows
df = sns.load_dataset('penguins')

# Drop rows with null values from the original dataframe
df.dropna(inplace=True)

# Define the features (X) and target (Y) after dropping nulls
X = df.drop('species', axis=1)
Y = df['species']

# Map the target variable to numerical values
Y = Y.map({'Adelie': 0, 'Chinstrap':1, 'Gentoo':2})

# Perform one-hot encoding on 'sex' and label encoding on 'island'
X = pd.get_dummies(X, columns=['sex'], drop_first=True)
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X['island'] = le.fit_transform(X['island'])


X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=40)
print(X_train.shape)
# Out:
# (233, 6)

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier()

model1 = rfc.fit(X_train, y_train)
prediction1 = model1.predict(X_test)

print("Acc on training data: {:,.3f}".format(rfc.score(X_train, y_train)))
print("Acc on test data: {:,.3f}".format(rfc.score(X_test, y_test)))
# Out:
# Acc on training data: 1.000
# Acc on test data: 1.000

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
print(confusion_matrix(y_test, prediction1))
# Out:
# [[41  0  0]
#  [ 0 23  0]
#  [ 0  0 36]]

# %%
print(classification_report(y_test, prediction1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        41
#            1       1.00      1.00      1.00        23
#            2       1.00      1.00      1.00        36
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# %%
models=[]

models.append(('KNN', KNeighborsClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
models.append(('rfc', RandomForestClassifier()))

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# %%
# evaluate each model

results =[]
names=[]
for name , model in models:
    kfold=KFold(n_splits=10, random_state=None)
    cv_results= cross_val_score(model, X_train, y_train, cv=kfold,scoring='accuracy')
    results.append(cv_results)
    names.append(name)

    msg= '%s:, %f, (%f)' % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# KNN:, 0.755616, (0.060228)
# NB:, 0.961413, (0.048394)
# SVM:, 0.747283, (0.076540)
# rfc:, 0.986957, (0.039130)

# %%
# make predictions on test datasets

rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
predictions= rfc.predict(X_test)
print(accuracy_score(y_test, predictions))
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        41
#            1       1.00      1.00      1.00        23
#            2       1.00      1.00      1.00        36
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
#
# [[41  0  0]
#  [ 0 23  0]
#  [ 0  0 36]]

# %%
NB = GaussianNB()
NB.fit(X_train, y_train)
predcitions = NB.predict(X_test)
print(accuracy_score(y_test, predictions))
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        41
#            1       1.00      1.00      1.00        23
#            2       1.00      1.00      1.00        36
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100
#
# [[41  0  0]
#  [ 0 23  0]
#  [ 0  0 36]]

# %%
KNN = KNeighborsClassifier()
KNN.fit(X_train, y_train)
predictions= KNN.predict(X_test)
print(accuracy_score(y_test, predictions))
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
# 0.78
#               precision    recall  f1-score   support
#
#            0       0.68      0.95      0.80        41
#            1       0.91      0.43      0.59        23
#            2       0.91      0.81      0.85        36
#
#     accuracy                           0.78       100
#    macro avg       0.83      0.73      0.75       100
# weighted avg       0.82      0.78      0.77       100
#
# [[39  0  2]
#  [12 10  1]
#  [ 6  1 29]]
